# %% [markdown]
# # PART 2

# %%
from package.gui_utils import load_rirs, plot_rirs
from part2 import create_micsigs
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# Out:
# Mac OS Version is 12.6 and patch enabled so applying the patch
# Applyting Mac OS 12.3+ Alpha Channel fix.  Your default Alpha Channel is now 0.99
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from package.gui_utils import load_rirs, plot_rirs
# ----> 2 from part2 import create_micsigs
#       3 import numpy as np
#       4 import sklearn
#
# File ~/Documents/Brain_Computer_Interface_Directional_Accounstric_Zoom/part2.py:46
#      43     # print(mic_recs)
#      44     return mic_recs, speech_recs, noise_recs
# ---> 46 acousticScenario = load_rirs(path="/Users/rudi/Dropbox/MSc EE/P&D ISSP/Brain_Computer_Interface_Directional_Acoustic_Zoom/rirs/rirs_20230216_16h10m08s.pkl.gz")
#      48 mic, _, _ = create_micsigs(acousticScenario=acousticScenario)
#      50 fig, axs = plt.subplots(2, 1)
#
# File ~/Documents/Brain_Computer_Interface_Directional_Accounstric_Zoom/package/gui_utils.py:870, in load_rirs(path)
#     868 def load_rirs(path) -> RIRg_GUI:
# --> 870     RIRGUIobject = pickle.load(gzip.open(path, 'r'))
#     872     return RIRGUIobject
#
# File /usr/local/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/gzip.py:58, in open(filename, mode, compresslevel, encoding, errors, newline)
#      56 gz_mode = mode.replace("t", "")
#      57 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58     binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59 elif hasattr(filename, "read") or hasattr(filename, "write"):
#      60     binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# File /usr/local/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/gzip.py:173, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     171     mode += 'b'
#     172 if fileobj is None:
# --> 173     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     174 if filename is None:
#     175     filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/rudi/Dropbox/MSc EE/P&D ISSP/Brain_Computer_Interface_Directional_Acoustic_Zoom/rirs/rirs_20230216_16h10m08s.pkl.gz'

# %%
acousticScenario = load_rirs(path="/Users/andyvandervaeren/Documents/Brain_Computer_Interface_Directional_Accounstric_Zoom/rirs/.gitignore")
mic, speech, noise = create_micsigs(acousticScenario=acousticScenario)
print(noise)
fig, axs = plt.subplots(2, 1)
axs[0].plot(mic[0])
axs[1].plot(mic)
# Out:
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 6
#       4 print(mic)
#       5 fig, axs = plt.subplots(2, 1)
# ----> 6 axs[0].plot(mic[0])
#       7 axs[1].plot(mic)
#
# IndexError: list index out of range
