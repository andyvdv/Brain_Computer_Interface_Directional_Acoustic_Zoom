# %%
from model import CNN
import os
data_folder = os.getcwd() + '/data/eeg'
all_files = [f for f in os.listdir(data_folder) if f.endswith('.npz')]

model = CNN(time_window=10, 
            files=all_files, 
            subjects=["sub-005"], 
            batch_size=1, 
            model='simple', 
            patience=4, 
            channels=64,
            dropout=False)

# model.tune_complex_model()

model.train_model()
model.test_model()
model.plot_history()
# model.tune_complex_model()
# Out:
# train files: ['sub-005_-_audiobook_5_2.npz', 'sub-005_-_audiobook_6_1.npz', 'sub-005_-_audiobook_1.npz', 'sub-005_-_audiobook_5_1.npz', 'sub-005_-_audiobook_6_2.npz', 'sub-005_-_audiobook_2_1.npz', 'sub-005_-_audiobook_5_3.npz', 'sub-005_-_audiobook_3.npz']
# val files: ['sub-005_-_audiobook_5_2.npz', 'sub-005_-_audiobook_6_1.npz', 'sub-005_-_audiobook_1.npz', 'sub-005_-_audiobook_5_1.npz', 'sub-005_-_audiobook_6_2.npz', 'sub-005_-_audiobook_2_1.npz', 'sub-005_-_audiobook_5_3.npz', 'sub-005_-_audiobook_3.npz']
# test files: ['sub-005_-_audiobook_5_2.npz', 'sub-005_-_audiobook_6_1.npz', 'sub-005_-_audiobook_1.npz', 'sub-005_-_audiobook_5_1.npz', 'sub-005_-_audiobook_6_2.npz', 'sub-005_-_audiobook_2_1.npz', 'sub-005_-_audiobook_5_3.npz', 'sub-005_-_audiobook_3.npz']
# Num GPUs Available:  1
# Epoch 1/100
# 2023-04-23 22:15:02.257019: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# ...

# %%
from model import CNN
import os
data_folder = os.getcwd() + '/data/eeg'
all_files = [f for f in os.listdir(data_folder) if f.endswith('.npz')]

model = CNN(time_window=10, 
            files=all_files, 
            subjects=["sub-002", "sub-005"], 
            batch_size=10, 
            model='complex', 
            patience=3, 
            learning_rate=0.0001,
            channels=64,
            dropout=True)

model.train_model()
model.test_model()
model.plot_history()
# Out:
# train files: ['sub-002_-_audiobook_5_2.npz', 'sub-002_-_audiobook_2_1.npz', 'sub-005_-_audiobook_6_2.npz', 'sub-002_-_audiobook_3.npz', 'sub-005_-_audiobook_5_1.npz', 'sub-002_-_audiobook_5_1.npz', 'sub-005_-_audiobook_5_2.npz', 'sub-005_-_audiobook_3.npz', 'sub-002_-_audiobook_6_1.npz', 'sub-005_-_audiobook_1.npz', 'sub-002_-_audiobook_5_3.npz', 'sub-005_-_audiobook_6_1.npz', 'sub-002_-_audiobook_6_2.npz', 'sub-005_-_audiobook_2_1.npz', 'sub-002_-_audiobook_1.npz', 'sub-002_-_audiobook_4.npz', 'sub-005_-_audiobook_5_3.npz']
# ...

# %%
from model import CNN
import os
from keras.utils import plot_model
data_folder = os.getcwd() + '/data/eeg'
all_files = [f for f in os.listdir(data_folder) if f.endswith('.npz')]

model = CNN(time_window=5, 
            files=all_files, 
            subjects=["sub-005"], 
            batch_size=1, 
            model='complex', 
            patience=3, 
            learning_rate=0.0001,
            channels=64,
            dropout=True)


plot_model(model.model, to_file='model.png', show_shapes=True)
# model.train_model()
# model.test_model()
# model.plot_history()
# model.tune_complex_model()
# Out:
# train files: ['sub-005_-_audiobook_5_2.npz', 'sub-005_-_audiobook_1.npz', 'sub-005_-_audiobook_6_2.npz', 'sub-005_-_audiobook_5_1.npz', 'sub-005_-_audiobook_6_1.npz', 'sub-005_-_audiobook_2_1.npz', 'sub-005_-_audiobook_5_3.npz', 'sub-005_-_audiobook_3.npz']
# val files: ['sub-005_-_audiobook_5_2.npz', 'sub-005_-_audiobook_1.npz', 'sub-005_-_audiobook_6_2.npz', 'sub-005_-_audiobook_5_1.npz', 'sub-005_-_audiobook_6_1.npz', 'sub-005_-_audiobook_2_1.npz', 'sub-005_-_audiobook_5_3.npz', 'sub-005_-_audiobook_3.npz']
# test files: ['sub-005_-_audiobook_5_2.npz', 'sub-005_-_audiobook_1.npz', 'sub-005_-_audiobook_6_2.npz', 'sub-005_-_audiobook_5_1.npz', 'sub-005_-_audiobook_6_1.npz', 'sub-005_-_audiobook_2_1.npz', 'sub-005_-_audiobook_5_3.npz', 'sub-005_-_audiobook_3.npz']
# Num GPUs Available:  1

# %%
from model import CNN
import os
data_folder = os.getcwd() + '/data/eeg'
all_files = [f for f in os.listdir(data_folder) if f.endswith('.npz')]

model = CNN(time_window=10, 
            files=all_files, 
            subjects=["sub-013"], 
            batch_size=5, 
            model='simple', 
            patience=3,
            channels=64,
            dropout=True)

model.train_model()
model.test_model()
model.plot_history()
# Out:
# train files: ['sub-013_-_audiobook_5_1.npz', 'sub-013_-_audiobook_1.npz', 'sub-013_-_audiobook_6_1.npz', 'sub-013_-_audiobook_5_2.npz', 'sub-013_-_audiobook_6_2.npz', 'sub-013_-_audiobook_2_1.npz', 'sub-013_-_audiobook_4.npz', 'sub-013_-_audiobook_5_3.npz', 'sub-013_-_audiobook_3.npz']
# val files: ['sub-013_-_audiobook_5_1.npz', 'sub-013_-_audiobook_1.npz', 'sub-013_-_audiobook_6_1.npz', 'sub-013_-_audiobook_5_2.npz', 'sub-013_-_audiobook_6_2.npz', 'sub-013_-_audiobook_2_1.npz', 'sub-013_-_audiobook_4.npz', 'sub-013_-_audiobook_5_3.npz', 'sub-013_-_audiobook_3.npz']
# test files: ['sub-013_-_audiobook_5_1.npz', 'sub-013_-_audiobook_1.npz', 'sub-013_-_audiobook_6_1.npz', 'sub-013_-_audiobook_5_2.npz', 'sub-013_-_audiobook_6_2.npz', 'sub-013_-_audiobook_2_1.npz', 'sub-013_-_audiobook_4.npz', 'sub-013_-_audiobook_5_3.npz', 'sub-013_-_audiobook_3.npz']
# Num GPUs Available:  1
# Epoch 1/100
# ...

# %%
from model import CNN
import os
data_folder = os.getcwd() + '/data/eeg'
all_files = [f for f in os.listdir(data_folder) if f.endswith('.npz')]

model = CNN(time_window=10, 
            files=all_files, 
            subjects=["sub-001", "sub-002", "sub-003", "sub-004"],
            batch_size=20, 
            model='complex', 
            patience=3, 
            channels=64,
            dropout=True)

model.train_model()
model.test_model()
model.plot_history()
# Out:
# train files: ['sub-003_-_audiobook_5_2.npz', 'sub-001_-_audiobook_1.npz', 'sub-004_-_audiobook_3.npz', 'sub-003_-_audiobook_5_3.npz', 'sub-003_-_audiobook_3.npz', 'sub-004_-_audiobook_2_1.npz', 'sub-001_-_audiobook_5_2.npz', 'sub-003_-_audiobook_6_1.npz', 'sub-003_-_audiobook_4.npz', 'sub-002_-_audiobook_4.npz', 'sub-002_-_audiobook_5_1.npz', 'sub-003_-_audiobook_1.npz', 'sub-002_-_audiobook_6_2.npz', 'sub-002_-_audiobook_3.npz', 'sub-002_-_audiobook_5_3.npz', 'sub-003_-_audiobook_5_1.npz', 'sub-003_-_audiobook_2_1.npz', 'sub-004_-_audiobook_1.npz', 'sub-002_-_audiobook_6_1.npz', 'sub-003_-_audiobook_6_2.npz', 'sub-002_-_audiobook_5_2.npz', 'sub-002_-_audiobook_1.npz', 'sub-001_-_audiobook_5_1.npz', 'sub-002_-_audiobook_2_1.npz']
# ...
