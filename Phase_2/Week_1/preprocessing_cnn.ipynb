# %%
from brian2 import Hz, kHz
from brian2hears import Sound, erbspace, Gammatone, Filterbank
from scipy.signal import butter, filtfilt, sosfiltfilt, lfilter
import librosa as lb
import os, sys
sys.path.append(os.getcwd())
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
class EnvelopeFromGammatoneFilterbank(Filterbank):
    """Converts the output of a GammatoneFilterbank to an envelope."""

    def __init__(self, source):
        """Initialize the envelope transformation.

        Parameters
        ----------
        source : Gammatone
            Gammatone filterbank output to convert to envelope
        """
        super().__init__(source)

        self.nchannels = 1

    def buffer_apply(self, input_):
        # 6. take absolute value of the input_
        compressed_subbands = np.abs(input_)**0.6

        combined_envelope = np.sum(compressed_subbands, axis=1)

        return  combined_envelope.reshape(combined_envelope.shape[0], 1)

# %%
# # Convert the numpy array to a Sound object
# audio_sound = Sound(audio_signal, samplerate=sr*Hz)

# num_filters = 28
# center_freqs = np.linspace(50*Hz, 5*kHz, num_filters)
# gammatone_filterbank = Gammatone(audio_sound, center_freqs)

# envelope_calcuation = EnvelopeFromGammatoneFilterbank(gammatone_filterbank)
# combined_envelope = envelope_calcuation.process()

# # Plot the combined envelope
# plt.plot(combined_envelope)
# plt.title("Combined Envelope")

# plt.show()

# %%
# # Choose the frequency range based on the method
# low_freq = 1
# high_freq = 32

# # Design a Butterworth bandpass filter
# order = 4
# nyquist = 0.5 * sr
# low = low_freq / nyquist
# high = high_freq / nyquist
# sos = butter(order, [low, high], btype='band', output='sos')

# normalized_envelope = combined_envelope / np.max(combined_envelope)
# print(normalized_envelope.shape)
# filtered_envelope = sosfiltfilt(sos, normalized_envelope[:, 0])


# print(filtered_envelope)

# # Choose the downsampling rate based on the method
# downsampling_rate = 64

# resampled_envelope = lb.resample(filtered_envelope, orig_sr=sr, target_sr=downsampling_rate)
# print(resampled_envelope.shape)
# plt.plot(resampled_envelope)
# plt.show()

# %%
def bandpass_filter(signal, fs):
    sos = butter(1, [1, 32], fs=fs, btype='band', output='sos')
    filtered_signal = sosfiltfilt(sos, signal, axis=0)
    return filtered_signal

def downsample_eeg(filtered_eeg, fs, target_fs):
    downsampled_eeg = lb.resample(filtered_eeg.T, orig_sr=fs, target_sr=target_fs).T
    return downsampled_eeg

def get_audio_file(filepath):
    audio_signal, sr = lb.load(filepath, sr=44100)
    
    return audio_signal, sr

def audio_data_preprocessing(audio_signal, sr=44100):
    # AUDIO DATA PREPROCESSING
    audio_sound = Sound(audio_signal, samplerate=sr*Hz)

    num_filters = 28
    center_freqs = np.linspace(50*Hz, 5*kHz, num_filters)
    gammatone_filterbank = Gammatone(audio_sound, center_freqs)

    envelope_calcuation = EnvelopeFromGammatoneFilterbank(gammatone_filterbank)
    combined_envelope = envelope_calcuation.process()

    # Design a Butterworth bandpass filter
    # nyquist = 0.5 * sr
    # low = low_freq / nyquist
    # high = high_freq / nyquist
    # sos = butter(4, [low, high], btype='band', output='sos')

    # normalized_envelope = combined_envelope / np.max(combined_envelope)
    # filtered_envelope = sosfiltfilt(sos, normalized_envelope[:, 0])
    print(combined_envelope.shape)
    filtered_envelope = bandpass_filter(combined_envelope.flatten(), sr)

    # Choose the downsampling rate based on the method
    target_sr = 64 # DEEP LEARNING

    resampled_envelope = lb.resample(filtered_envelope, orig_sr=sr, target_sr=target_sr)
#     plt.plot(resampled_envelope)
#     plt.show()
    return resampled_envelope

def eeg_data_preprocessing(eeg):
    # EEG DATA PREPROCESSING
    # Filter the EEG signals using a bandpass filter
    fs = 128
    filtered_eeg = bandpass_filter(eeg, fs)
    # Downsample the EEG signals
    target_sr = 64  # For linear regression
    downsampled_eeg = lb.resample(filtered_eeg, orig_sr=fs, target_sr=target_sr, axis=0)
    return downsampled_eeg

# %%
def preprocess(filename, verbose=False):
    filepath = "../data/eeg/" + filename
    eeg_data = np.load(filepath, allow_pickle=True)
    eeg = eeg_data['eeg']
    fs = eeg_data['fs']
    subject = str(eeg_data['subject'])
    stimulus_attended = str(eeg_data['stimulus_attended']).replace(".wav", "")
    stimulus_unattended = str(eeg_data['stimulus_unattended']).replace(".wav", "")
    print("====================== EEG DATA ======================") if verbose else None
    print(f"Attended stimulus: {stimulus_attended}") if verbose else None
    print(f"Unattended stimulus: {stimulus_unattended}") if verbose else None
    print(f"Sampling rate: {fs} Hz") if verbose else None
    print(f"Subject: {subject}") if verbose else None
    print("======================================================\n") if verbose else None

    print("=> PROCESSING EEG DATA") if verbose else None
    eeg_preprocessed = eeg_data_preprocessing(eeg)
    np.save("../data/train_cnn/"+ filename.replace(".npz", "") + ".npy", eeg_preprocessed)
    print(f"=> EEG PREPROCESSED DATA SHAPE: {eeg_preprocessed.shape}") if verbose else None
    print("=> DONE\n") if verbose else None

    print("=> RETRIEVING AUDIO DATA OF ATTENDED STIMULUS") if verbose else None
    attended_audio_signal, sr = get_audio_file("../data/stimuli/" + str(eeg_data["stimulus_attended"]))
    print("================= ATTENDED AUDIO DATA ================") if verbose else None
    print(f"File name: {eeg_data['stimulus_attended']}") if verbose else None
    print(f"Audio signal length: {len(attended_audio_signal)}") if verbose else None
    print(f"Sampling rate: {sr} Hz") if verbose else None
    print("======================================================\n") if verbose else None

    if os.path.isfile("../data/train_cnn/" + stimulus_attended + ".npy"):
        print("ATTENDED AUDIO DATA ALREADY PREPROCESSED") if verbose else None
        attended_preprocessed = np.load("../data/train_cnn/" + stimulus_attended + ".npy")
    else:
        print("=> PROCESSING ATTENDED AUDIO DATA") if verbose else None
        attended_preprocessed = audio_data_preprocessing(attended_audio_signal)
        np.save("../data/train_cnn/" + stimulus_attended + ".npy", attended_preprocessed)
    print("=> DONE\n") if verbose else None

    print("=> RETRIEVING AUDIO DATA OF UNATTENDED STIMULUS") if verbose else None
    unattended_audio_signal, sr = get_audio_file("../data/stimuli/" + str(eeg_data["stimulus_unattended"]))
    
    print("================= UNATTENDED AUDIO DATA ================") if verbose else None
    print(f"File name: {eeg_data['stimulus_unattended']}") if verbose else None
    print(f"Audio signal length: {len(unattended_audio_signal)}") if verbose else None
    print(f"Sampling rate: {sr} Hz") if verbose else None
    print("======================================================\n") if verbose else None

    if os.path.isfile("../data/train_cnn/" + stimulus_unattended + ".npy"):
        print("UNATTENDED AUDIO DATA ALREADY PREPROCESSED") if verbose else None
        unattended_preprocessed = np.load("../data/train_cnn/" + stimulus_unattended + ".npy")
    else:
        print("=> PROCESSING UNATTENDED AUDIO DATA") if verbose else None
        unattended_preprocessed = audio_data_preprocessing(unattended_audio_signal)
        np.save("../data/train_cnn/"+stimulus_unattended+ ".npy", unattended_preprocessed)
    print("=> DONE\n") if verbose else None

# %%
for index, filename in enumerate(os.listdir("../data/eeg/")):
    print("PREPROCESSING FILE {filename} ({index}/{total})".format(filename=filename, index=index, total=len(os.listdir("../data/eeg/"))))
    if filename.endswith(".npz"):
        preprocess(filename, verbose=False)
    print(f"PREPROCESSED ALL OF {filename}")
    # except:
    #     print(f"COULD NOT PREPROCESS ALL OF {filename}")
#     print(filename)
# Out:
# PREPROCESSING FILE sub-008_-_audiobook_6_1.npz (0/310)
# (36761165, 1)
# (42025682, 1)
# PREPROCESSED ALL OF sub-008_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-004_-_audiobook_3.npz (1/310)
# (42444051, 1)
# (41314177, 1)
# PREPROCESSED ALL OF sub-004_-_audiobook_3.npz
# PREPROCESSING FILE sub-013_-_audiobook_6_2.npz (2/310)
# (36753542, 1)
# PREPROCESSED ALL OF sub-013_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-019_-_audiobook_4.npz (3/310)
# (35872129, 1)
# PREPROCESSED ALL OF sub-019_-_audiobook_4.npz
# PREPROCESSING FILE sub-018_-_audiobook_5_3.npz (4/310)
# (39959390, 1)
# PREPROCESSED ALL OF sub-018_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-035_-_podcast_6.npz (5/310)
# (37252858, 1)
# (43893761, 1)
# PREPROCESSED ALL OF sub-035_-_podcast_6.npz
# PREPROCESSING FILE sub-035_-_audiobook_1.npz (6/310)
# PREPROCESSED ALL OF sub-035_-_audiobook_1.npz
# PREPROCESSING FILE sub-002_-_audiobook_5_1.npz (7/310)
# (40116309, 1)
# PREPROCESSED ALL OF sub-002_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-019_-_audiobook_5_2.npz (8/310)
# PREPROCESSED ALL OF sub-019_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-011_-_audiobook_6_1.npz (9/310)
# PREPROCESSED ALL OF sub-011_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-017_-_audiobook_2_1.npz (10/310)
# (34879241, 1)
# PREPROCESSED ALL OF sub-017_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-019_-_audiobook_5_3.npz (11/310)
# PREPROCESSED ALL OF sub-019_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-012_-_audiobook_6_2.npz (12/310)
# PREPROCESSED ALL OF sub-012_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-001_-_audiobook_5_2.npz (13/310)
# PREPROCESSED ALL OF sub-001_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-029_-_audiobook_1.npz (14/310)
# (32071681, 1)
# PREPROCESSED ALL OF sub-029_-_audiobook_1.npz
# PREPROCESSING FILE sub-035_-_podcast_7.npz (15/310)
# (43440641, 1)
# PREPROCESSED ALL OF sub-035_-_podcast_7.npz
# PREPROCESSING FILE sub-018_-_audiobook_5_2.npz (16/310)
# PREPROCESSED ALL OF sub-018_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-016_-_audiobook_2_1.npz (17/310)
# PREPROCESSED ALL OF sub-016_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-010_-_audiobook_6_1.npz (18/310)
# PREPROCESSED ALL OF sub-010_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-001_-_audiobook_1.npz (19/310)
# PREPROCESSED ALL OF sub-001_-_audiobook_1.npz
# PREPROCESSING FILE sub-003_-_audiobook_5_1.npz (20/310)
# PREPROCESSED ALL OF sub-003_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-018_-_audiobook_3.npz (21/310)
# PREPROCESSED ALL OF sub-018_-_audiobook_3.npz
# PREPROCESSING FILE sub-008_-_audiobook_6_2.npz (22/310)
# PREPROCESSED ALL OF sub-008_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-015_-_audiobook_2_1.npz (23/310)
# PREPROCESSED ALL OF sub-015_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-013_-_audiobook_6_1.npz (24/310)
# PREPROCESSED ALL OF sub-013_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-018_-_audiobook_1.npz (25/310)
# PREPROCESSED ALL OF sub-018_-_audiobook_1.npz
# PREPROCESSING FILE sub-003_-_audiobook_5_3.npz (26/310)
# PREPROCESSED ALL OF sub-003_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-035_-_podcast_5.npz (27/310)
# (32949505, 1)
# PREPROCESSED ALL OF sub-035_-_podcast_5.npz
# PREPROCESSING FILE sub-002_-_audiobook_5_2.npz (28/310)
# PREPROCESSED ALL OF sub-002_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-019_-_audiobook_5_1.npz (29/310)
# PREPROCESSED ALL OF sub-019_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-030_-_audiobook_1.npz (30/310)
# (42067969, 1)
# PREPROCESSED ALL OF sub-030_-_audiobook_1.npz
# PREPROCESSING FILE sub-011_-_audiobook_6_2.npz (31/310)
# PREPROCESSED ALL OF sub-011_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-002_-_audiobook_5_3.npz (32/310)
# PREPROCESSED ALL OF sub-002_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-012_-_audiobook_6_1.npz (33/310)
# PREPROCESSED ALL OF sub-012_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-014_-_audiobook_2_1.npz (34/310)
# PREPROCESSED ALL OF sub-014_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-001_-_audiobook_5_1.npz (35/310)
# PREPROCESSED ALL OF sub-001_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-018_-_audiobook_5_1.npz (36/310)
# PREPROCESSED ALL OF sub-018_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-010_-_audiobook_6_2.npz (37/310)
# PREPROCESSED ALL OF sub-010_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-003_-_audiobook_5_2.npz (38/310)
# PREPROCESSED ALL OF sub-003_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-004_-_audiobook_1.npz (39/310)
# PREPROCESSED ALL OF sub-004_-_audiobook_1.npz
# PREPROCESSING FILE sub-005_-_audiobook_3.npz (40/310)
# PREPROCESSED ALL OF sub-005_-_audiobook_3.npz
# PREPROCESSING FILE sub-007_-_audiobook_5_1.npz (41/310)
# PREPROCESSED ALL OF sub-007_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-012_-_audiobook_2_1.npz (42/310)
# PREPROCESSED ALL OF sub-012_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-014_-_audiobook_6_1.npz (43/310)
# PREPROCESSED ALL OF sub-014_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-018_-_audiobook_4.npz (44/310)
# PREPROCESSED ALL OF sub-018_-_audiobook_4.npz
# PREPROCESSING FILE sub-039_-_podcast_12.npz (45/310)
# (46400256, 1)
# (36837966, 1)
# PREPROCESSED ALL OF sub-039_-_podcast_12.npz
# PREPROCESSING FILE sub-034_-_audiobook_1.npz (46/310)
# (44677633, 1)
# PREPROCESSED ALL OF sub-034_-_audiobook_1.npz
# PREPROCESSING FILE sub-037_-_audiobook_9_1.npz (47/310)
# (28532845, 1)
# PREPROCESSED ALL OF sub-037_-_audiobook_9_1.npz
# PREPROCESSING FILE .DS_Store (48/310)
# PREPROCESSED ALL OF .DS_Store
# PREPROCESSING FILE sub-005_-_audiobook_5_2.npz (49/310)
# PREPROCESSED ALL OF sub-005_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-016_-_audiobook_6_2.npz (50/310)
# PREPROCESSED ALL OF sub-016_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-005_-_audiobook_5_3.npz (51/310)
# PREPROCESSED ALL OF sub-005_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-015_-_audiobook_6_1.npz (52/310)
# PREPROCESSED ALL OF sub-015_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-013_-_audiobook_2_1.npz (53/310)
# PREPROCESSED ALL OF sub-013_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-006_-_audiobook_5_1.npz (54/310)
# PREPROCESSED ALL OF sub-006_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-028_-_audiobook_1.npz (55/310)
# (5265629, 1)
# PREPROCESSED ALL OF sub-028_-_audiobook_1.npz
# PREPROCESSING FILE sub-032_-_podcast_5.npz (56/310)
# PREPROCESSED ALL OF sub-032_-_podcast_5.npz
# PREPROCESSING FILE sub-037_-_podcast_9.npz (57/310)
# (52541440, 1)
# (39690241, 1)
# PREPROCESSED ALL OF sub-037_-_podcast_9.npz
# PREPROCESSING FILE sub-019_-_audiobook_3.npz (58/310)
# PREPROCESSED ALL OF sub-019_-_audiobook_3.npz
# PREPROCESSING FILE sub-007_-_audiobook_5_2.npz (59/310)
# PREPROCESSED ALL OF sub-007_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-014_-_audiobook_6_2.npz (60/310)
# PREPROCESSED ALL OF sub-014_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-019_-_audiobook_1.npz (61/310)
# PREPROCESSED ALL OF sub-019_-_audiobook_1.npz
# PREPROCESSING FILE sub-032_-_podcast_7.npz (62/310)
# PREPROCESSED ALL OF sub-032_-_podcast_7.npz
# PREPROCESSING FILE sub-006_-_audiobook_5_3.npz (63/310)
# PREPROCESSED ALL OF sub-006_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-039_-_podcast_11.npz (64/310)
# PREPROCESSED ALL OF sub-039_-_podcast_11.npz
# PREPROCESSING FILE sub-038_-_podcast_9.npz (65/310)
# PREPROCESSED ALL OF sub-038_-_podcast_9.npz
# PREPROCESSING FILE sub-005_-_audiobook_5_1.npz (66/310)
# PREPROCESSED ALL OF sub-005_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-031_-_audiobook_1.npz (67/310)
# (10384990, 1)
# PREPROCESSED ALL OF sub-031_-_audiobook_1.npz
# PREPROCESSING FILE sub-016_-_audiobook_6_1.npz (68/310)
# PREPROCESSED ALL OF sub-016_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-010_-_audiobook_2_1.npz (69/310)
# PREPROCESSED ALL OF sub-010_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-015_-_audiobook_6_2.npz (70/310)
# PREPROCESSED ALL OF sub-015_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-039_-_podcast_10.npz (71/310)
# PREPROCESSED ALL OF sub-039_-_podcast_10.npz
# PREPROCESSING FILE sub-032_-_podcast_6.npz (72/310)
# PREPROCESSED ALL OF sub-032_-_podcast_6.npz
# PREPROCESSING FILE sub-008_-_audiobook_2_1.npz (73/310)
# PREPROCESSED ALL OF sub-008_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-011_-_audiobook_2_1.npz (74/310)
# PREPROCESSED ALL OF sub-011_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-005_-_audiobook_1.npz (75/310)
# PREPROCESSED ALL OF sub-005_-_audiobook_1.npz
# PREPROCESSING FILE sub-007_-_audiobook_5_3.npz (76/310)
# PREPROCESSED ALL OF sub-007_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-006_-_audiobook_3.npz (77/310)
# PREPROCESSED ALL OF sub-006_-_audiobook_3.npz
# PREPROCESSING FILE sub-012_-_audiobook_5_2.npz (78/310)
# PREPROCESSED ALL OF sub-012_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-037_-_podcast_12.npz (79/310)
# PREPROCESSED ALL OF sub-037_-_podcast_12.npz
# PREPROCESSING FILE sub-037_-_audiobook_1.npz (80/310)
# PREPROCESSED ALL OF sub-037_-_audiobook_1.npz
# PREPROCESSING FILE sub-013_-_audiobook_5_3.npz (81/310)
# PREPROCESSED ALL OF sub-013_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-039_-_audiobook_9_1.npz (82/310)
# PREPROCESSED ALL OF sub-039_-_audiobook_9_1.npz
# PREPROCESSING FILE sub-005_-_audiobook_2_1.npz (83/310)
# PREPROCESSED ALL OF sub-005_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-036_-_podcast_8.npz (84/310)
# PREPROCESSED ALL OF sub-036_-_podcast_8.npz
# PREPROCESSING FILE sub-003_-_audiobook_6_1.npz (85/310)
# PREPROCESSED ALL OF sub-003_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-010_-_audiobook_5_1.npz (86/310)
# PREPROCESSED ALL OF sub-010_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-018_-_audiobook_6_2.npz (87/310)
# PREPROCESSED ALL OF sub-018_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-013_-_audiobook_5_2.npz (88/310)
# PREPROCESSED ALL OF sub-013_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-008_-_audiobook_5_1.npz (89/310)
# PREPROCESSED ALL OF sub-008_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-011_-_audiobook_5_1.npz (90/310)
# PREPROCESSED ALL OF sub-011_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-003_-_audiobook_1.npz (91/310)
# PREPROCESSED ALL OF sub-003_-_audiobook_1.npz
# PREPROCESSING FILE sub-019_-_audiobook_6_2.npz (92/310)
# PREPROCESSED ALL OF sub-019_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-002_-_audiobook_6_1.npz (93/310)
# PREPROCESSED ALL OF sub-002_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-004_-_audiobook_2_1.npz (94/310)
# PREPROCESSED ALL OF sub-004_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-012_-_audiobook_5_3.npz (95/310)
# PREPROCESSED ALL OF sub-012_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-038_-_audiobook_9_1.npz (96/310)
# PREPROCESSED ALL OF sub-038_-_audiobook_9_1.npz
# PREPROCESSING FILE sub-007_-_audiobook_4.npz (97/310)
# PREPROCESSED ALL OF sub-007_-_audiobook_4.npz
# PREPROCESSING FILE sub-033_-_podcast_5.npz (98/310)
# PREPROCESSED ALL OF sub-033_-_podcast_5.npz
# PREPROCESSING FILE sub-033_-_podcast_7.npz (99/310)
# PREPROCESSED ALL OF sub-033_-_podcast_7.npz
# PREPROCESSING FILE sub-007_-_audiobook_2_1.npz (100/310)
# PREPROCESSED ALL OF sub-007_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-012_-_audiobook_5_1.npz (101/310)
# PREPROCESSED ALL OF sub-012_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-014_-_audiobook_1_1.npz (102/310)
# (20171809, 1)
# PREPROCESSED ALL OF sub-014_-_audiobook_1_1.npz
# PREPROCESSING FILE sub-039_-_podcast_9.npz (103/310)
# PREPROCESSED ALL OF sub-039_-_podcast_9.npz
# PREPROCESSING FILE sub-022_-_audiobook_1_2_shifted.npz (104/310)
# (18463844, 1)
# PREPROCESSED ALL OF sub-022_-_audiobook_1_2_shifted.npz
# PREPROCESSING FILE sub-011_-_audiobook_5_3.npz (105/310)
# PREPROCESSED ALL OF sub-011_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-003_-_audiobook_3.npz (106/310)
# PREPROCESSED ALL OF sub-003_-_audiobook_3.npz
# PREPROCESSING FILE sub-037_-_podcast_11.npz (107/310)
# PREPROCESSED ALL OF sub-037_-_podcast_11.npz
# PREPROCESSING FILE sub-008_-_audiobook_5_3.npz (108/310)
# PREPROCESSED ALL OF sub-008_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-032_-_audiobook_8_1.npz (109/310)
# PREPROCESSED ALL OF sub-032_-_audiobook_8_1.npz
# PREPROCESSING FILE sub-003_-_audiobook_6_2.npz (110/310)
# PREPROCESSED ALL OF sub-003_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-032_-_audiobook_1.npz (111/310)
# PREPROCESSED ALL OF sub-032_-_audiobook_1.npz
# PREPROCESSING FILE sub-010_-_audiobook_5_2.npz (112/310)
# PREPROCESSED ALL OF sub-010_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-018_-_audiobook_6_1.npz (113/310)
# PREPROCESSED ALL OF sub-018_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-010_-_audiobook_5_3.npz (114/310)
# PREPROCESSED ALL OF sub-010_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-013_-_audiobook_5_1.npz (115/310)
# PREPROCESSED ALL OF sub-013_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-008_-_audiobook_5_2.npz (116/310)
# PREPROCESSED ALL OF sub-008_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-037_-_podcast_10.npz (117/310)
# PREPROCESSED ALL OF sub-037_-_podcast_10.npz
# PREPROCESSING FILE sub-006_-_audiobook_2_1.npz (118/310)
# PREPROCESSED ALL OF sub-006_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-002_-_audiobook_4.npz (119/310)
# PREPROCESSED ALL OF sub-002_-_audiobook_4.npz
# PREPROCESSING FILE sub-011_-_audiobook_5_2.npz (120/310)
# PREPROCESSED ALL OF sub-011_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-019_-_audiobook_6_1.npz (121/310)
# PREPROCESSED ALL OF sub-019_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-002_-_audiobook_6_2.npz (122/310)
# PREPROCESSED ALL OF sub-002_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-033_-_audiobook_8_1.npz (123/310)
# PREPROCESSED ALL OF sub-033_-_audiobook_8_1.npz
# PREPROCESSING FILE sub-006_-_audiobook_1.npz (124/310)
# PREPROCESSED ALL OF sub-006_-_audiobook_1.npz
# PREPROCESSING FILE sub-033_-_podcast_6.npz (125/310)
# PREPROCESSED ALL OF sub-033_-_podcast_6.npz
# PREPROCESSING FILE sub-006_-_audiobook_6_1.npz (126/310)
# PREPROCESSED ALL OF sub-006_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-034_-_podcast_6.npz (127/310)
# PREPROCESSED ALL OF sub-034_-_podcast_6.npz
# PREPROCESSING FILE sub-015_-_audiobook_5_1.npz (128/310)
# PREPROCESSED ALL OF sub-015_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-007_-_audiobook_3.npz (129/310)
# PREPROCESSED ALL OF sub-007_-_audiobook_3.npz
# PREPROCESSING FILE sub-016_-_audiobook_5_3.npz (130/310)
# PREPROCESSED ALL OF sub-016_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-036_-_audiobook_1.npz (131/310)
# PREPROCESSED ALL OF sub-036_-_audiobook_1.npz
# PREPROCESSING FILE sub-035_-_audiobook_8_1.npz (132/310)
# PREPROCESSED ALL OF sub-035_-_audiobook_8_1.npz
# PREPROCESSING FILE sub-017_-_audiobook_5_2.npz (133/310)
# PREPROCESSED ALL OF sub-017_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-019_-_audiobook_2_1.npz (134/310)
# PREPROCESSED ALL OF sub-019_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-014_-_audiobook_5_1.npz (135/310)
# PREPROCESSED ALL OF sub-014_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-038_-_podcast_12.npz (136/310)
# PREPROCESSED ALL OF sub-038_-_podcast_12.npz
# PREPROCESSING FILE sub-007_-_audiobook_6_1.npz (137/310)
# PREPROCESSED ALL OF sub-007_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-016_-_audiobook_5_2.npz (138/310)
# PREPROCESSED ALL OF sub-016_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-002_-_audiobook_1.npz (139/310)
# PREPROCESSED ALL OF sub-002_-_audiobook_1.npz
# PREPROCESSING FILE sub-018_-_audiobook_2_1.npz (140/310)
# PREPROCESSED ALL OF sub-018_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-005_-_audiobook_6_2.npz (141/310)
# PREPROCESSED ALL OF sub-005_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-006_-_audiobook_4.npz (142/310)
# PREPROCESSED ALL OF sub-006_-_audiobook_4.npz
# PREPROCESSING FILE sub-034_-_audiobook_8_1.npz (143/310)
# PREPROCESSED ALL OF sub-034_-_audiobook_8_1.npz
# PREPROCESSING FILE sub-034_-_podcast_7.npz (144/310)
# PREPROCESSED ALL OF sub-034_-_podcast_7.npz
# PREPROCESSING FILE sub-034_-_podcast_5.npz (145/310)
# PREPROCESSED ALL OF sub-034_-_podcast_5.npz
# PREPROCESSING FILE sub-006_-_audiobook_6_2.npz (146/310)
# PREPROCESSED ALL OF sub-006_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-015_-_audiobook_5_2.npz (147/310)
# PREPROCESSED ALL OF sub-015_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-002_-_audiobook_3.npz (148/310)
# PREPROCESSED ALL OF sub-002_-_audiobook_3.npz
# PREPROCESSING FILE sub-038_-_podcast_10.npz (149/310)
# PREPROCESSED ALL OF sub-038_-_podcast_10.npz
# PREPROCESSING FILE sub-014_-_audiobook_5_3.npz (150/310)
# PREPROCESSED ALL OF sub-014_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-002_-_audiobook_2_1.npz (151/310)
# PREPROCESSED ALL OF sub-002_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-033_-_audiobook_1.npz (152/310)
# PREPROCESSED ALL OF sub-033_-_audiobook_1.npz
# PREPROCESSING FILE sub-017_-_audiobook_5_1.npz (153/310)
# PREPROCESSED ALL OF sub-017_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-036_-_audiobook_8_1.npz (154/310)
# PREPROCESSED ALL OF sub-036_-_audiobook_8_1.npz
# PREPROCESSING FILE sub-014_-_audiobook_5_2.npz (155/310)
# PREPROCESSED ALL OF sub-014_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-007_-_audiobook_6_2.npz (156/310)
# PREPROCESSED ALL OF sub-007_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-038_-_podcast_11.npz (157/310)
# PREPROCESSED ALL OF sub-038_-_podcast_11.npz
# PREPROCESSING FILE sub-016_-_audiobook_5_1.npz (158/310)
# PREPROCESSED ALL OF sub-016_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-003_-_audiobook_4.npz (159/310)
# PREPROCESSED ALL OF sub-003_-_audiobook_4.npz
# PREPROCESSING FILE sub-005_-_audiobook_6_1.npz (160/310)
# PREPROCESSED ALL OF sub-005_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-003_-_audiobook_2_1.npz (161/310)
# PREPROCESSED ALL OF sub-003_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-015_-_audiobook_5_3.npz (162/310)
# PREPROCESSED ALL OF sub-015_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-007_-_audiobook_1.npz (163/310)
# PREPROCESSED ALL OF sub-007_-_audiobook_1.npz
# PREPROCESSING FILE sub-023_-_audiobook_1_1_shifted.npz (164/310)
# (20171809, 1)
# PREPROCESSED ALL OF sub-023_-_audiobook_1_1_shifted.npz
# PREPROCESSING FILE sub-023_-_audiobook_3.npz (165/310)
# PREPROCESSED ALL OF sub-023_-_audiobook_3.npz
# PREPROCESSING FILE sub-014_-_audiobook_1_2_shifted.npz (166/310)
# PREPROCESSED ALL OF sub-014_-_audiobook_1_2_shifted.npz
# PREPROCESSING FILE sub-027_-_audiobook_7_2.npz (167/310)
# (10666089, 1)
# PREPROCESSED ALL OF sub-027_-_audiobook_7_2.npz
# PREPROCESSING FILE sub-024_-_audiobook_5_2.npz (168/310)
# PREPROCESSED ALL OF sub-024_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-012_-_audiobook_1.npz (169/310)
# PREPROCESSED ALL OF sub-012_-_audiobook_1.npz
# PREPROCESSING FILE sub-026_-_audiobook_5_1.npz (170/310)
# PREPROCESSED ALL OF sub-026_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-025_-_audiobook_5_3.npz (171/310)
# PREPROCESSED ALL OF sub-025_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-016_-_audiobook_4.npz (172/310)
# PREPROCESSED ALL OF sub-016_-_audiobook_4.npz
# PREPROCESSING FILE sub-025_-_audiobook_5_2.npz (173/310)
# PREPROCESSED ALL OF sub-025_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-023_-_audiobook_1_2.npz (174/310)
# (18463844, 1)
# PREPROCESSED ALL OF sub-023_-_audiobook_1_2.npz
# PREPROCESSING FILE sub-040_-_audiobook_1.npz (175/310)
# PREPROCESSED ALL OF sub-040_-_audiobook_1.npz
# PREPROCESSING FILE sub-027_-_audiobook_7_3.npz (176/310)
# (10836420, 1)
# PREPROCESSED ALL OF sub-027_-_audiobook_7_3.npz
# PREPROCESSING FILE sub-024_-_audiobook_5_3.npz (177/310)
# PREPROCESSED ALL OF sub-024_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-026_-_audiobook_1.npz (178/310)
# PREPROCESSED ALL OF sub-026_-_audiobook_1.npz
# PREPROCESSING FILE sub-021_-_audiobook_1_1.npz (179/310)
# PREPROCESSED ALL OF sub-021_-_audiobook_1_1.npz
# PREPROCESSING FILE sub-034_-_podcast_8.npz (180/310)
# PREPROCESSED ALL OF sub-034_-_podcast_8.npz
# PREPROCESSING FILE sub-022_-_audiobook_4.npz (181/310)
# PREPROCESSED ALL OF sub-022_-_audiobook_4.npz
# PREPROCESSING FILE sub-026_-_audiobook_3.npz (182/310)
# PREPROCESSED ALL OF sub-026_-_audiobook_3.npz
# PREPROCESSING FILE sub-024_-_audiobook_5_1.npz (183/310)
# PREPROCESSED ALL OF sub-024_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-027_-_audiobook_7_1.npz (184/310)
# (50043393, 1)
# PREPROCESSED ALL OF sub-027_-_audiobook_7_1.npz
# PREPROCESSING FILE sub-022_-_audiobook_1_1.npz (185/310)
# PREPROCESSED ALL OF sub-022_-_audiobook_1_1.npz
# PREPROCESSING FILE sub-026_-_audiobook_5_2.npz (186/310)
# PREPROCESSED ALL OF sub-026_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-013_-_audiobook_4.npz (187/310)
# PREPROCESSED ALL OF sub-013_-_audiobook_4.npz
# PREPROCESSING FILE sub-025_-_audiobook_5_1.npz (188/310)
# PREPROCESSED ALL OF sub-025_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-012_-_audiobook_3.npz (189/310)
# PREPROCESSED ALL OF sub-012_-_audiobook_3.npz
# PREPROCESSING FILE sub-026_-_audiobook_5_3.npz (190/310)
# PREPROCESSED ALL OF sub-026_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-022_-_audiobook_3.npz (191/310)
# PREPROCESSED ALL OF sub-022_-_audiobook_3.npz
# PREPROCESSING FILE sub-020_-_audiobook_5_3.npz (192/310)
# PREPROCESSED ALL OF sub-020_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-021_-_audiobook_1_2_shifted.npz (193/310)
# PREPROCESSED ALL OF sub-021_-_audiobook_1_2_shifted.npz
# PREPROCESSING FILE sub-027_-_audiobook_7_4.npz (194/310)
# (14398698, 1)
# PREPROCESSED ALL OF sub-027_-_audiobook_7_4.npz
# PREPROCESSING FILE sub-023_-_audiobook_5_1.npz (195/310)
# PREPROCESSED ALL OF sub-023_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-021_-_audiobook_5_2.npz (196/310)
# PREPROCESSED ALL OF sub-021_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-013_-_audiobook_1.npz (197/310)
# PREPROCESSED ALL OF sub-013_-_audiobook_1.npz
# PREPROCESSING FILE sub-036_-_podcast_7.npz (198/310)
# PREPROCESSED ALL OF sub-036_-_podcast_7.npz
# PREPROCESSING FILE sub-031_-_podcast_3.npz (199/310)
# PREPROCESSED ALL OF sub-031_-_podcast_3.npz
# PREPROCESSING FILE sub-028_-_podcast_2.npz (200/310)
# PREPROCESSED ALL OF sub-028_-_podcast_2.npz
# PREPROCESSING FILE sub-028_-_podcast_3.npz (201/310)
# (5337107, 1)
# PREPROCESSED ALL OF sub-028_-_podcast_3.npz
# PREPROCESSING FILE sub-016_-_audiobook_3.npz (202/310)
# PREPROCESSED ALL OF sub-016_-_audiobook_3.npz
# PREPROCESSING FILE sub-022_-_audiobook_5_1.npz (203/310)
# PREPROCESSED ALL OF sub-022_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-031_-_podcast_2.npz (204/310)
# PREPROCESSED ALL OF sub-031_-_podcast_2.npz
# PREPROCESSING FILE sub-036_-_podcast_6.npz (205/310)
# PREPROCESSED ALL OF sub-036_-_podcast_6.npz
# PREPROCESSING FILE sub-021_-_audiobook_5_3.npz (206/310)
# PREPROCESSED ALL OF sub-021_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-027_-_podcast_1.npz (207/310)
# PREPROCESSED ALL OF sub-027_-_podcast_1.npz
# PREPROCESSING FILE sub-027_-_audiobook_7_5.npz (208/310)
# PREPROCESSED ALL OF sub-027_-_audiobook_7_5.npz
# PREPROCESSING FILE sub-027_-_audiobook_1.npz (209/310)
# PREPROCESSED ALL OF sub-027_-_audiobook_1.npz
# PREPROCESSING FILE sub-020_-_audiobook_5_2.npz (210/310)
# PREPROCESSED ALL OF sub-020_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-023_-_audiobook_4.npz (211/310)
# PREPROCESSED ALL OF sub-023_-_audiobook_4.npz
# PREPROCESSING FILE sub-040_-_audiobook_9_1.npz (212/310)
# PREPROCESSED ALL OF sub-040_-_audiobook_9_1.npz
# PREPROCESSING FILE sub-033_-_podcast_8.npz (213/310)
# PREPROCESSED ALL OF sub-033_-_podcast_8.npz
# PREPROCESSING FILE sub-027_-_podcast_3.npz (214/310)
# PREPROCESSED ALL OF sub-027_-_podcast_3.npz
# PREPROCESSING FILE sub-023_-_audiobook_5_2.npz (215/310)
# PREPROCESSED ALL OF sub-023_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-021_-_audiobook_5_1.npz (216/310)
# PREPROCESSED ALL OF sub-021_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-012_-_audiobook_4.npz (217/310)
# PREPROCESSED ALL OF sub-012_-_audiobook_4.npz
# PREPROCESSING FILE sub-016_-_audiobook_1.npz (218/310)
# PREPROCESSED ALL OF sub-016_-_audiobook_1.npz
# PREPROCESSING FILE sub-022_-_audiobook_5_3.npz (219/310)
# PREPROCESSED ALL OF sub-022_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-028_-_podcast_1.npz (220/310)
# PREPROCESSED ALL OF sub-028_-_podcast_1.npz
# PREPROCESSING FILE sub-022_-_audiobook_5_2.npz (221/310)
# PREPROCESSED ALL OF sub-022_-_audiobook_5_2.npz
# PREPROCESSING FILE sub-031_-_podcast_1.npz (222/310)
# PREPROCESSED ALL OF sub-031_-_podcast_1.npz
# PREPROCESSING FILE sub-036_-_podcast_5.npz (223/310)
# PREPROCESSED ALL OF sub-036_-_podcast_5.npz
# PREPROCESSING FILE sub-013_-_audiobook_3.npz (224/310)
# PREPROCESSED ALL OF sub-013_-_audiobook_3.npz
# PREPROCESSING FILE sub-023_-_audiobook_5_3.npz (225/310)
# PREPROCESSED ALL OF sub-023_-_audiobook_5_3.npz
# PREPROCESSING FILE sub-027_-_podcast_2.npz (226/310)
# PREPROCESSED ALL OF sub-027_-_podcast_2.npz
# PREPROCESSING FILE sub-026_-_audiobook_4.npz (227/310)
# PREPROCESSED ALL OF sub-026_-_audiobook_4.npz
# PREPROCESSING FILE sub-020_-_audiobook_5_1.npz (228/310)
# PREPROCESSED ALL OF sub-020_-_audiobook_5_1.npz
# PREPROCESSING FILE sub-031_-_audiobook_7_5.npz (229/310)
# PREPROCESSED ALL OF sub-031_-_audiobook_7_5.npz
# PREPROCESSING FILE sub-021_-_audiobook_3.npz (230/310)
# PREPROCESSED ALL OF sub-021_-_audiobook_3.npz
# PREPROCESSING FILE sub-030_-_podcast_3.npz (231/310)
# PREPROCESSED ALL OF sub-030_-_podcast_3.npz
# PREPROCESSING FILE sub-038_-_audiobook_1.npz (232/310)
# PREPROCESSED ALL OF sub-038_-_audiobook_1.npz
# PREPROCESSING FILE sub-029_-_podcast_2.npz (233/310)
# PREPROCESSED ALL OF sub-029_-_podcast_2.npz
# PREPROCESSING FILE sub-029_-_audiobook_7_4.npz (234/310)
# PREPROCESSED ALL OF sub-029_-_audiobook_7_4.npz
# PREPROCESSING FILE sub-025_-_audiobook_6_2.npz (235/310)
# PREPROCESSED ALL OF sub-025_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-030_-_audiobook_7_4.npz (236/310)
# PREPROCESSED ALL OF sub-030_-_audiobook_7_4.npz
# PREPROCESSING FILE sub-010_-_audiobook_1.npz (237/310)
# PREPROCESSED ALL OF sub-010_-_audiobook_1.npz
# PREPROCESSING FILE sub-021_-_audiobook_2_1.npz (238/310)
# PREPROCESSED ALL OF sub-021_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-014_-_audiobook_4.npz (239/310)
# PREPROCESSED ALL OF sub-014_-_audiobook_4.npz
# PREPROCESSING FILE sub-028_-_audiobook_7_5.npz (240/310)
# PREPROCESSED ALL OF sub-028_-_audiobook_7_5.npz
# PREPROCESSING FILE sub-028_-_audiobook_7_4.npz (241/310)
# PREPROCESSED ALL OF sub-028_-_audiobook_7_4.npz
# PREPROCESSING FILE sub-024_-_audiobook_6_2.npz (242/310)
# PREPROCESSED ALL OF sub-024_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-008_-_audiobook_4.npz (243/310)
# PREPROCESSED ALL OF sub-008_-_audiobook_4.npz
# PREPROCESSING FILE sub-015_-_audiobook_3.npz (244/310)
# PREPROCESSED ALL OF sub-015_-_audiobook_3.npz
# PREPROCESSING FILE sub-030_-_audiobook_7_5.npz (245/310)
# PREPROCESSED ALL OF sub-030_-_audiobook_7_5.npz
# PREPROCESSING FILE sub-024_-_audiobook_1.npz (246/310)
# PREPROCESSED ALL OF sub-024_-_audiobook_1.npz
# PREPROCESSING FILE sub-029_-_podcast_3.npz (247/310)
# PREPROCESSED ALL OF sub-029_-_podcast_3.npz
# PREPROCESSING FILE sub-029_-_audiobook_7_5.npz (248/310)
# PREPROCESSED ALL OF sub-029_-_audiobook_7_5.npz
# PREPROCESSING FILE sub-030_-_podcast_2.npz (249/310)
# PREPROCESSED ALL OF sub-030_-_podcast_2.npz
# PREPROCESSING FILE sub-020_-_audiobook_2_1.npz (250/310)
# PREPROCESSED ALL OF sub-020_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-026_-_audiobook_6_1.npz (251/310)
# PREPROCESSED ALL OF sub-026_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-031_-_audiobook_7_4.npz (252/310)
# PREPROCESSED ALL OF sub-031_-_audiobook_7_4.npz
# PREPROCESSING FILE sub-031_-_audiobook_7_6.npz (253/310)
# PREPROCESSED ALL OF sub-031_-_audiobook_7_6.npz
# PREPROCESSING FILE sub-023_-_audiobook_2_1.npz (254/310)
# PREPROCESSED ALL OF sub-023_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-025_-_audiobook_6_1.npz (255/310)
# PREPROCESSED ALL OF sub-025_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-029_-_podcast_1.npz (256/310)
# PREPROCESSED ALL OF sub-029_-_podcast_1.npz
# PREPROCESSING FILE sub-024_-_audiobook_3.npz (257/310)
# PREPROCESSED ALL OF sub-024_-_audiobook_3.npz
# PREPROCESSING FILE sub-032_-_podcast_8.npz (258/310)
# PREPROCESSED ALL OF sub-032_-_podcast_8.npz
# PREPROCESSING FILE sub-011_-_audiobook_4.npz (259/310)
# PREPROCESSED ALL OF sub-011_-_audiobook_4.npz
# PREPROCESSING FILE sub-015_-_audiobook_1.npz (260/310)
# PREPROCESSED ALL OF sub-015_-_audiobook_1.npz
# PREPROCESSING FILE sub-028_-_audiobook_7_6.npz (261/310)
# PREPROCESSED ALL OF sub-028_-_audiobook_7_6.npz
# PREPROCESSING FILE sub-024_-_audiobook_6_1.npz (262/310)
# PREPROCESSED ALL OF sub-024_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-022_-_audiobook_2_1.npz (263/310)
# PREPROCESSED ALL OF sub-022_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-010_-_audiobook_3.npz (264/310)
# PREPROCESSED ALL OF sub-010_-_audiobook_3.npz
# PREPROCESSING FILE sub-030_-_audiobook_7_6.npz (265/310)
# PREPROCESSED ALL OF sub-030_-_audiobook_7_6.npz
# PREPROCESSING FILE sub-029_-_audiobook_7_6.npz (266/310)
# PREPROCESSED ALL OF sub-029_-_audiobook_7_6.npz
# PREPROCESSING FILE sub-030_-_podcast_1.npz (267/310)
# PREPROCESSED ALL OF sub-030_-_podcast_1.npz
# PREPROCESSING FILE sub-026_-_audiobook_6_2.npz (268/310)
# PREPROCESSED ALL OF sub-026_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-031_-_audiobook_7_3.npz (269/310)
# PREPROCESSED ALL OF sub-031_-_audiobook_7_3.npz
# PREPROCESSING FILE sub-040_-_podcast_10.npz (270/310)
# PREPROCESSED ALL OF sub-040_-_podcast_10.npz
# PREPROCESSING FILE sub-020_-_audiobook_3.npz (271/310)
# PREPROCESSED ALL OF sub-020_-_audiobook_3.npz
# PREPROCESSING FILE sub-039_-_audiobook_1.npz (272/310)
# PREPROCESSED ALL OF sub-039_-_audiobook_1.npz
# PREPROCESSING FILE sub-024_-_audiobook_2_1.npz (273/310)
# PREPROCESSED ALL OF sub-024_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-022_-_audiobook_6_1.npz (274/310)
# PREPROCESSED ALL OF sub-022_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-029_-_audiobook_7_2.npz (275/310)
# PREPROCESSED ALL OF sub-029_-_audiobook_7_2.npz
# PREPROCESSING FILE sub-011_-_audiobook_1.npz (276/310)
# PREPROCESSED ALL OF sub-011_-_audiobook_1.npz
# PREPROCESSING FILE sub-030_-_audiobook_7_2.npz (277/310)
# PREPROCESSED ALL OF sub-030_-_audiobook_7_2.npz
# PREPROCESSING FILE sub-020_-_audiobook_6_2.npz (278/310)
# PREPROCESSED ALL OF sub-020_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-015_-_audiobook_4.npz (279/310)
# PREPROCESSED ALL OF sub-015_-_audiobook_4.npz
# PREPROCESSING FILE sub-028_-_audiobook_7_3.npz (280/310)
# PREPROCESSED ALL OF sub-028_-_audiobook_7_3.npz
# PREPROCESSING FILE sub-008_-_audiobook_3.npz (281/310)
# PREPROCESSED ALL OF sub-008_-_audiobook_3.npz
# PREPROCESSING FILE sub-023_-_audiobook_6_1.npz (282/310)
# PREPROCESSED ALL OF sub-023_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-025_-_audiobook_2_1.npz (283/310)
# PREPROCESSED ALL OF sub-025_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-028_-_audiobook_7_2.npz (284/310)
# PREPROCESSED ALL OF sub-028_-_audiobook_7_2.npz
# PREPROCESSING FILE sub-014_-_audiobook_3.npz (285/310)
# PREPROCESSED ALL OF sub-014_-_audiobook_3.npz
# PREPROCESSING FILE sub-030_-_audiobook_7_3.npz (286/310)
# PREPROCESSED ALL OF sub-030_-_audiobook_7_3.npz
# PREPROCESSING FILE sub-035_-_podcast_8.npz (287/310)
# PREPROCESSED ALL OF sub-035_-_podcast_8.npz
# PREPROCESSING FILE sub-029_-_audiobook_7_3.npz (288/310)
# PREPROCESSED ALL OF sub-029_-_audiobook_7_3.npz
# PREPROCESSING FILE sub-025_-_audiobook_1.npz (289/310)
# PREPROCESSED ALL OF sub-025_-_audiobook_1.npz
# PREPROCESSING FILE sub-021_-_audiobook_4.npz (290/310)
# PREPROCESSED ALL OF sub-021_-_audiobook_4.npz
# PREPROCESSING FILE sub-021_-_audiobook_6_2.npz (291/310)
# PREPROCESSED ALL OF sub-021_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-040_-_podcast_11.npz (292/310)
# PREPROCESSED ALL OF sub-040_-_podcast_11.npz
# PREPROCESSING FILE sub-031_-_audiobook_7_2.npz (293/310)
# PREPROCESSED ALL OF sub-031_-_audiobook_7_2.npz
# PREPROCESSING FILE sub-022_-_audiobook_6_2.npz (294/310)
# PREPROCESSED ALL OF sub-022_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-025_-_audiobook_3.npz (295/310)
# PREPROCESSED ALL OF sub-025_-_audiobook_3.npz
# PREPROCESSING FILE sub-029_-_audiobook_7_1.npz (296/310)
# PREPROCESSED ALL OF sub-029_-_audiobook_7_1.npz
# PREPROCESSING FILE sub-010_-_audiobook_4.npz (297/310)
# PREPROCESSED ALL OF sub-010_-_audiobook_4.npz
# PREPROCESSING FILE sub-030_-_audiobook_7_1.npz (298/310)
# PREPROCESSED ALL OF sub-030_-_audiobook_7_1.npz
# PREPROCESSING FILE sub-020_-_audiobook_6_1.npz (299/310)
# PREPROCESSED ALL OF sub-020_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-026_-_audiobook_2_1.npz (300/310)
# PREPROCESSED ALL OF sub-026_-_audiobook_2_1.npz
# PREPROCESSING FILE sub-023_-_audiobook_6_2.npz (301/310)
# PREPROCESSED ALL OF sub-023_-_audiobook_6_2.npz
# PREPROCESSING FILE sub-008_-_audiobook_1.npz (302/310)
# PREPROCESSED ALL OF sub-008_-_audiobook_1.npz
# PREPROCESSING FILE sub-028_-_audiobook_7_1.npz (303/310)
# PREPROCESSED ALL OF sub-028_-_audiobook_7_1.npz
# PREPROCESSING FILE sub-040_-_podcast_9.npz (304/310)
# PREPROCESSED ALL OF sub-040_-_podcast_9.npz
# PREPROCESSING FILE sub-011_-_audiobook_3.npz (305/310)
# PREPROCESSED ALL OF sub-011_-_audiobook_3.npz
# PREPROCESSING FILE sub-024_-_audiobook_4.npz (306/310)
# PREPROCESSED ALL OF sub-024_-_audiobook_4.npz
# PREPROCESSING FILE sub-021_-_audiobook_6_1.npz (307/310)
# PREPROCESSED ALL OF sub-021_-_audiobook_6_1.npz
# PREPROCESSING FILE sub-040_-_podcast_12.npz (308/310)
# PREPROCESSED ALL OF sub-040_-_podcast_12.npz
# PREPROCESSING FILE sub-031_-_audiobook_7_1.npz (309/310)
# PREPROCESSED ALL OF sub-031_-_audiobook_7_1.npz
